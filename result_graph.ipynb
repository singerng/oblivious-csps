# %%
from matplotlib import pyplot

# %%
classes = [53, 103, 203, 303, 403]
smaller = [53, 103, 203, 303]
onehalf = [0.481871,0.483568,0.484423,0.4847096]
optimal = [0.482308,0.484008,0.484850,0.485133,0.485275]
tobeat = [0.485281, 0.485281, 0.485281, 0.485281, 0.485281]
optimalbound = [0.48603, 0.48603, 0.48603, 0.48603, 0.48603]
pyplot.plot(classes, optimal, label="b=1.8625/3.8625")
pyplot.plot(smaller, onehalf, label="b=1/2")
pyplot.plot(classes, tobeat, label="Current Bound on PL Sigmoid with b=1/2")
pyplot.plot(classes, optimalbound, label="Current Bound on PL Sigmoid with b=1.8625/3.8625")
pyplot.legend()
pyplot.title("Approximation Ratios for Discretization of PL Sigmoid Functions")
pyplot.xlabel("Number of Bias Classes")
pyplot.ylabel("Approximation Ratio")
# Out:
# Text(0, 0.5, 'Approximation Ratio')
